# %%
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from PIL import Image
import cv2
import keras
from keras.applications.vgg16 import preprocess_input,VGG16                                #Import Libraries needed
from keras.applications.vgg19 import preprocess_input,VGG19
import tensorflow as tf
from keras.models import Sequential,Model
from keras.layers import MaxPooling2D,Conv2D,Dense,BatchNormalization,Dropout,GlobalAveragePooling2D,Flatten,Input
from keras.callbacks import EarlyStopping,ReduceLROnPlateau
from sklearn.metrics import classification_report
from keras.utils.vis_utils import plot_model
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/gdrive/')                                                                  #Drive mounting
# Out:
# Mounted at /gdrive/

# %%
data_dir= '/gdrive/MyDrive/AdvancedSignalProcessing/ED6001_data/Training'                 #give training data path here
print(data_dir)
# Out:
# /gdrive/MyDrive/AdvancedSignalProcessing/ED6001_data/Training

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm
import os
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, TensorBoard, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
from PIL import Image
from IPython.display import display, clear_output
import ipywidgets as widgets
import io

# %%
#data preparation

# %%
labels = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
train_X = []
train_Y  = []
test_X = []
test_Y = []
image_size=150
for label in labels:
    train_path = os.path.join(data_dir,label)
    for file in tqdm(os.listdir(train_path)):
        image = cv2.imread(os.path.join(train_path, file))
        image = cv2.resize(image, (image_size, image_size))
        train_X.append(image)
        train_Y.append(label)
    
train_X = np.array(train_X)
# Out:
# 100%|██████████| 826/826 [03:16<00:00,  4.21it/s]
# 100%|██████████| 822/822 [03:07<00:00,  4.39it/s]
# 100%|██████████| 395/395 [01:29<00:00,  4.40it/s]
# 100%|██████████| 827/827 [02:55<00:00,  4.72it/s]

# %%
for label in labels:
  
    test_path = os.path.join('/gdrive/MyDrive/AdvancedSignalProcessing/ED6001_data/Testing',label)    #give test data ath here
    for file in tqdm(os.listdir(test_path)):
        image = cv2.imread(os.path.join(test_path, file))
        image = cv2.resize(image, (image_size, image_size))
        test_X.append(image)
        test_Y.append(label)
    
test_X = np.array(test_X)
# Out:
# 100%|██████████| 100/100 [00:20<00:00,  4.92it/s]
# 100%|██████████| 115/115 [00:24<00:00,  4.66it/s]
# 100%|██████████| 105/105 [00:18<00:00,  5.65it/s]
# 100%|██████████| 74/74 [00:14<00:00,  5.21it/s]

# %%
fig, ax = plt.subplots(1,4, figsize=(20,20))
k = 0
for i in range(0,4):
    if i==0: idx=0
    elif i==1: idx=827
    elif i==2: idx=1649
    else: idx=2045
    ax[k].imshow(train_X[idx])
    ax[k].set_title(train_Y[idx])
    ax[k].axis('off')
    k+=1

# %%
train_X, train_Y = shuffle(train_X, train_Y, random_state=28)                          #shuffling training data
print(train_X.shape)
# Out:
# (2870, 150, 150, 3)

# %%
#One hot encoding

# %%
train_Y_ = []
for i in train_Y:
    train_Y_.append(labels.index(i))
train_Y = train_Y_

train_Y = tf.keras.utils.to_categorical(train_Y)

test_Y_ = []
for i in test_Y:
    test_Y_.append(labels.index(i))
test_Y = test_Y_

test_Y = tf.keras.utils.to_categorical(test_Y)

# %%
train_X, X_val, train_Y, Y_val = train_test_split(train_X, train_Y, test_size=0.2, random_state=28)

# %%
#Transfer learning
#EfficientNetB0 is taken as base model and new layers are added to it for classification.

# %%
base_model = EfficientNetB0(weights='imagenet', include_top=False, input_shape=(image_size, image_size, 3))
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# 16719872/16705208 [==============================] - 0s 0us/step

# %%
from keras.layers import GlobalAveragePooling2D, Dropout, Dense
from keras.models import Model
model = base_model.output
model = GlobalAveragePooling2D()(model)
model = Dense(4, activation='softmax')(model)
model = Model(inputs = base_model.input, outputs=model)

# %%
model.compile(loss='categorical_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.3, patience=2, min_denta=0.0001, mode='auto', verbose=1)
tensorboard = TensorBoard(log_dir='logs')
checkpoint = ModelCheckpoint("classification.h5", monitor='val_accuracy', save_best_only=True, mode='auto', verbose=1)

# %%
#ImageDataGenerator is used for data augmentation pupose.
#Image augmentation is a technique of applying different transformations to original images which results in multiple transformed copies of the same image.
#like rotated,flipped etc.

# %%
data_generation= ImageDataGenerator(
featurewise_center=False,
samplewise_center=False,
featurewise_std_normalization=False,
samplewise_std_normalization=False,
zca_whitening=False,
rotation_range=10,
zoom_range=0.1,
width_shift_range=0.1,
horizontal_flip=False,
vertical_flip=False)

data_generation.fit(train_X)

# %%
history = model.fit_generator(data_generation.flow(train_X, train_Y, batch_size=32),
                              validation_data=(X_val, Y_val), 
                              epochs=10, 
                              verbose=1,
                            callbacks=[tensorboard, checkpoint, reduce_lr])
# Out:
# Epoch 1/10
# 72/72 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.8419
# Epoch 00001: val_accuracy improved from -inf to 0.46516, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 49s 387ms/step - loss: 0.4170 - accuracy: 0.8419 - val_loss: 4.5289 - val_accuracy: 0.4652 - lr: 0.0010
# Epoch 2/10
# 72/72 [==============================] - ETA: 0s - loss: 0.1910 - accuracy: 0.9342
# Epoch 00002: val_accuracy improved from 0.46516 to 0.58537, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 24s 328ms/step - loss: 0.1910 - accuracy: 0.9342 - val_loss: 1.5128 - val_accuracy: 0.5854 - lr: 0.0010
# Epoch 3/10
# 72/72 [==============================] - ETA: 0s - loss: 0.1368 - accuracy: 0.9512
# Epoch 00003: val_accuracy improved from 0.58537 to 0.85540, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 24s 328ms/step - loss: 0.1368 - accuracy: 0.9512 - val_loss: 0.6686 - val_accuracy: 0.8554 - lr: 0.0010
# Epoch 4/10
# 72/72 [==============================] - ETA: 0s - loss: 0.1242 - accuracy: 0.9569
# Epoch 00004: val_accuracy improved from 0.85540 to 0.89547, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 24s 332ms/step - loss: 0.1242 - accuracy: 0.9569 - val_loss: 0.5125 - val_accuracy: 0.8955 - lr: 0.0010
# Epoch 5/10
# 72/72 [==============================] - ETA: 0s - loss: 0.0720 - accuracy: 0.9752
# Epoch 00005: val_accuracy did not improve from 0.89547
# 72/72 [==============================] - 23s 315ms/step - loss: 0.0720 - accuracy: 0.9752 - val_loss: 0.4321 - val_accuracy: 0.8885 - lr: 0.0010
# Epoch 6/10
# 72/72 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9769
# Epoch 00006: val_accuracy did not improve from 0.89547
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 72/72 [==============================] - 23s 315ms/step - loss: 0.0707 - accuracy: 0.9769 - val_loss: 0.9297 - val_accuracy: 0.7439 - lr: 0.0010
# Epoch 7/10
# 72/72 [==============================] - ETA: 0s - loss: 0.0490 - accuracy: 0.9848
# Epoch 00007: val_accuracy improved from 0.89547 to 0.90244, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 24s 328ms/step - loss: 0.0490 - accuracy: 0.9848 - val_loss: 0.3518 - val_accuracy: 0.9024 - lr: 3.0000e-04
# Epoch 8/10
# 72/72 [==============================] - ETA: 0s - loss: 0.0232 - accuracy: 0.9926
# Epoch 00008: val_accuracy improved from 0.90244 to 0.91812, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 24s 326ms/step - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.2972 - val_accuracy: 0.9181 - lr: 3.0000e-04
# Epoch 9/10
# 72/72 [==============================] - ETA: 0s - loss: 0.0135 - accuracy: 0.9956
# Epoch 00009: val_accuracy improved from 0.91812 to 0.93206, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 24s 334ms/step - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.2483 - val_accuracy: 0.9321 - lr: 3.0000e-04
# Epoch 10/10
# 72/72 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9965
# Epoch 00010: val_accuracy improved from 0.93206 to 0.93554, saving model to brain_tumor_classification.h5
# 72/72 [==============================] - 24s 331ms/step - loss: 0.0123 - accuracy: 0.9965 - val_loss: 0.2447 - val_accuracy: 0.9355 - lr: 3.0000e-04

# %%
final_model = tf.keras.models.load_model('./classification.h5')

# %%
# Plot the loss and accuracy curves for training and validation 
fig, ax = plt.subplots(2,1)
ax[0].plot(history.history['loss'], color='b', label="Training loss")
ax[0].plot(history.history['val_loss'], color='r', label="validation loss",axes =ax[0])
legend = ax[0].legend(loc='best', shadow=True)

ax[1].plot(history.history['accuracy'], color='b', label="Training accuracy")
ax[1].plot(history.history['val_accuracy'], color='r',label="Validation accuracy")
legend = ax[1].legend(loc='best', shadow=True)

# %%
#Predictions on Test Datasets using EfficientnetB0 model
#metrics

prediction=np.argmax(model.predict(test_X),axis=1)
y= np.argmax(test_Y,axis=1)
print(classification_report(y,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.38      0.55       100
#            1       0.72      0.97      0.83       115
#            2       0.75      0.98      0.85       105
#            3       0.98      0.82      0.90        74
#
#     accuracy                           0.80       394
#    macro avg       0.86      0.79      0.78       394
# weighted avg       0.85      0.80      0.78       394

# %%
#Defining function for confusion matrix plot
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):

    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    #Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')


    fig, ax = plt.subplots(figsize=(7,7))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')


    #Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")
    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

np.set_printoptions(precision=2)

# %%
from sklearn.metrics import confusion_matrix
print(plot_confusion_matrix(y,prediction,classes = labels))
# Out:
# Confusion matrix, without normalization
# AxesSubplot(0.2563,0.147513;0.577817x0.831059)
